# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinprakash2004/python-coding/blob/main/pythoncoding_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("total_no_of_monkeys"))
k=int(input("eatable_bananas"))
j=int(input("eatable_peanuts"))
m=int(input("total_bananas"))
p=int(input("total_peanuts"))
if n<=0 or k<=0 or j<=0 or m<0 or p<0:
 print("invalid input")
else:
 nb=m//k
 np=p//j
 nt=nb+np
 monkeysleft=n-nt
 print("no_of_monkeys_left_on_the_tree:",monkeysleft)
# Out:
# total_no_of_monkeys20
# eatable_bananas2
# eatable_peanuts3
# total_bananas12
# total_peanuts12
# no_of_monkeys_left_on_the_tree: 10

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using + and -")
a=a+b
b=a-b
a=a-b
print ("a,b:",a,b)
# Out:
# enter the number  5
# enter the number  6
# a,b=: 5 6
#  using + and -
# a,b: 6 5

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using ^")
a=a^b
b=a^b
a=a^b
print ("a,b:",a,b)
# Out:
# enter the number  5
# enter the number  6
# a,b=: 5 6
#  using ^
# a,b: 6 5

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using temp")
temp=a
a=b
b=temp
print ("a,b:",a,b)
# Out:
# enter the number  5
# enter the number  6
# a,b=: 5 6
#  using temp
# a,b: 6 5

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using ,")
a,b=b,a
print ("a,b:",a,b)
# Out:
# enter the number  5
# enter the number  6
# a,b=: 5 6
#  using ,
# a,b: 6 5

# %%
n=int(input("enter the candies available in the jar"))
k=int(input("enter number of minimum candies "))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("sold=",M)
    print("Remaining=",R)
    C=int(input("do you want to continue(1or0):"))
# Out:
# enter the candies available in the jar20
# enter number of minimum candies 5
# Enter amout of candies:6
# sold= 6
# Remaining= 14
# do you want to continue(1or0):1
# Enter amout of candies:20
# sold= 20
# Remaining= 20
# do you want to continue(1or0):0
