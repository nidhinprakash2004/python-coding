# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinprakash2004/python-coding/blob/main/pythoncoding_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("total_no_of_monkeys"))
k=int(input("eatable_bananas"))
j=int(input("eatable_peanuts"))
m=int(input("total_bananas"))
p=int(input("total_peanuts"))
if n<=0 or k<=0 or j<=0 or m<0 or p<0:
 print("invalid input")
else:
 nb=m//k
 np=p//j
 nt=nb+np
 monkeysleft=n-nt
 print("no_of_monkeys_left_on_the_tree:",monkeysleft)
# Out:
# total_no_of_monkeys20
# eatable_bananas2
# eatable_peanuts3
# total_bananas12
# total_peanuts12
# no_of_monkeys_left_on_the_tree: 10

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using + and -")
a=a+b
b=a-b
a=a-b
print ("a,b:",a,b)

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using ^")
a=a^b
b=a^b
a=a^b
print ("a,b:",a,b)

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using temp")
temp=a
a=b
b=temp
print ("a,b:",a,b)

# %%
a=int(input("enter the number  "))
b=int(input("enter the number  "))
print("a,b=:",a,b)
print (" using ,")
a,b=b,a
print ("a,b:",a,b)

# %%
n=int(input("enter the candies available in the jar"))
k=int(input("enter number of minimum candies "))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("sold=",M)
    print("Remaining=",R)
    C=int(input("do you want to continue(1or0):"))

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("LIST:",list)

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
largest=max(num)
print(num)
print("largest element is",largest)

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
smallest=min(num)
print(num)
print("smallest element is",smallest)

# %%
a=int(input("Enter the number of elements"))
sum=0
for i in range(a):
  b=int(input("Enter the element"))
  sum=sum+b
print("The sum of elements is",sum)

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
print(num)
num.reverse()
print("reverse list is",num)

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")

# %%
n=int(input("enter the limit"))
arr=[]
for i in range (n):
  a=int(input("enter the element"))
  arr.append(a)
b=int(input("enter the element to check the occurence"))
arr.count(b)
print("occurence of an element",arr.count(b))

# %%
n = int(input("Enter number of elements: "))
a = []
for i in range(n):
    a.append(int(input("Enter element: ")))
a.sort()
print("Second largest:", a[-2])

# %%
# @title Default title text
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)

# %%
lt=[]
n=int(input("enter the size of the list:"))
for i in range(n):
  b=int(input("enter the element:"))
  lt.append(b)
print(lt)
lt.sort()
print("sorted array:",lt)

# %%
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# Enter elements:66 13 79
# [66, 13, 79]

# %%
arr =[10,20,30,40,50]
print(arr[1:4])
print(arr[:3])
print(arr[2:])
print(arr[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
r=int(input("No of rats:"))
u=int(input("No of units:"))
n=int(input("No of elements:"))
arr=list(map(int,input("Enter array").split()))
sum=0
h=0
for i in range(0,len(arr)):
  h+=1
  sum=sum+arr[i]
  if sum>=r*u:
    break
print("No of houses:",h)
# Out:
# No of rats:7
# No of units:2
# No of elements:8
# Enter array2 8 3 5 7 4 1 2
# No of houses: 4

# %%
s=input("enter a string")
print(s[::-1])
# Out:
# enter a string123
# 321

# %%
a=int(input("Enter your number:"))
rev=0
while a>0:
  num=a%10
  rev=rev*10+num
  a=a//10
print("Reversed number is:",rev)
# Out:
# Enter your number:123
# Reversed number is: 321

# %%
x=int(input("enter a number"))
sum=0
while x>0:
  sum+=x%10
  x=x//10
print(sum)
# Out:
# enter a number123
# 6

# %%
n = int(input("Enter a number: "))
largest = 0
while n > 0:
    digit = n % 10
    if digit > largest:
        largest = digit
    n = n // 10
print("Largest digit:", largest)
# Out:
# Enter a number: 951
# Largest digit: 9

# %%
n=int(input("enter the number:"))
dup=n
o=0
while n>0:
  r=n%10
  o=o*10+r
  n=n//10
if dup == o:
  print(dup,"is palindrome ")
else:
  print("The number is not a palindrome.")
# Out:
# enter the number:1233
# The number is not a palindrome.

# %%
str=input("Enter a string:")
if(str==str[::-1]):
  print("Palindrome")
else:
  print("Not palindrome")
# Out:
# Enter a string:malayalam
# Palindrome

# %%
str1=input("Enter the string:")
str2=input("Enter the string:")
if sorted(str1)==sorted(str2):
  print("anagram")
else:
  print("not anagram")
# Out:
# Enter the string:aslam
# Enter the string:ramees
# not anagram

# %%
s=input("Enter a string: ")
count=0
for I in s:
 count+=1
 print("Total characters without built in",count)
 print("Total characters with built in",len(s))
# Out:
# Enter a string: malayalam
# Total characters without built in 1
# Total characters with built in 9
# Total characters without built in 2
# Total characters with built in 9
# Total characters without built in 3
# Total characters with built in 9
# Total characters without built in 4
# Total characters with built in 9
# Total characters without built in 5
# Total characters with built in 9
# Total characters without built in 6
# Total characters with built in 9
# Total characters without built in 7
# Total characters with built in 9
# Total characters without built in 8
# Total characters with built in 9
# Total characters without built in 9
# Total characters with built in 9

# %%
s = input("Enter a string: ")
result = ""
for ch in s:
    if ch not in result:
        result += ch
print(result)
# Out:
# Enter a string: malayalam
# maly

# %%
s=input("Enter the string: ")
v,c=0,0
for i in s:
  if i in ("aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels: ",v,"\nNo of consonants: ",c)
# Out:
# Enter the string: malayalam
# No. of vowels:  4
# No of consonants:  5

# %%
a=input("Enter your string:")
space=""
for ch in a:
  if ch!=" ":
    space+=ch
print("The string without space:",space)
# Out:
# Enter your string:aslam sundaran
# The string without space: aslamsundaran

# %%
a = []
b = []
N1 = int(input("enter the value of N1:"))
N2 = int(input("enter the value of N2:"))
a = list(map(int, input("Enter the elements: ").split()))
b = list(map(int, input("Enter the elements: ").split()))
c = a + b
c = list(set(c))
c.sort()
n = len(c)
if n % 2 == 1:
  print("op=", c[n // 2])
else:
  median =( (c[n // 2 - 1] + c[n // 2]) / 2)
  print("op=", median)
# Out:
# enter the value of N1:2
# enter the value of N2:3
# Enter the elements: 2 3
# Enter the elements: 5 6 4
# op= 4

# %%
n=int(input("Enter the number:"))
p=bin(n)
b=p[2:]
b=b.replace('0','y')
b=b.replace('1','0')
b=b.replace('y','1')
print(int(b,2))
# Out:
# Enter the number:10
# 5
